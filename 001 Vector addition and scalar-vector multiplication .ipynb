# %%
import numpy as np
# A vector can be represented as a NumPy array
# Create a one-dimensional vector
vec = np.array([5,1,3])

print(vec)
# Out:
# [5 1 3]

# %%
# Create a two-dimensional vector
vec = np.array([[5,1,3],[2,1,4]])

print(vec)
# Out:
# [[5 1 3]
#  [2 1 4]]

# %%
import matplotlib.pyplot as plt

# %%
vec1 = np.array([1,5])
vec2 = np.array([4,-2])

x_vec1 = vec1[0]
y_vec1 = vec1[1]


x_vec2 = vec2[0]
y_vec2 = vec2[1]

vec = np.array([[x_vec1, x_vec2], [y_vec1, y_vec2]])

origin = np.zeros(vec.shape) # origin point

plt.figure(figsize=(6,6))
plt.quiver(*origin, *vec, color=['r','g','b'], scale=1, units='xy')

plt.grid()
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.gca().set_aspect('equal')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(6,6))
ax = fig.gca(projection='3d')

# Create a three-dimensional vector
# The first vector will be [7 7 7]
# The second vector will be [-5 2 2]
vec = np.array([[7,-5],[7,2],[7,2]])
origin = np.zeros(vec.shape) # origin point

ax.quiver(*origin, *vec)

plt.grid()
ax.set_zlim3d(-10, 10)
ax.set_ylim3d(-10, 10)
ax.set_xlim3d(-10, 10)  
plt.show()
# Out:
# C:\Users\mortezaa\AppData\Local\Temp\ipykernel_3276\435274080.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
# Indexing one-dimensional arrays

a = np.array([1, 2, 3, 4, 5, 6])

print("a[0]:", a[0])
print("a[5]:", a[5])
print("a[:3]:", a[:3])
print("a[1:3]:", a[1:3])
print("a[1:-2]:", a[1:-2])
# Out:
# a[0]: 1
# a[5]: 6
# a[:3]: [1 2 3]
# a[1:3]: [2 3]
# a[1:-2]: [2 3 4]

# %%
# Indexing two-dimensional arrays

a = np.array([[1, 2, 3], [4, 5, 6]])

print("a.shape:", a.shape)

print("a[0]:", a[0])
print("a[1]:", a[1])

print("a[:,0]:", a[:,0])
print("a[:,1]:", a[:,1])
print("a[:,2]:", a[:,2])
#
print("a[0,0]:", a[0,0])
print("a[2,2]:", a[1,2])
# Out:
# a.shape: (2, 3)
# a[0]: [1 2 3]
# a[1]: [4 5 6]
# a[:,0]: [1 4]
# a[:,1]: [2 5]
# a[:,2]: [3 6]
# a[0,0]: 1
# a[2,2]: 6
